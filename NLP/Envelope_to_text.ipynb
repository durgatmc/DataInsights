# %% [markdown]
# <a href="https://colab.research.google.com/github/durgatmc/DataInsights/blob/main/NLP/Envelope_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

###

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = "https://www.post.japanpost.jp/img/int/use/writing/label_normal_en.gif"

###

###

ner_results = nlp(example)
print(ner_results)

###
# Out:
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
#!pip install pytesseract
#!sudo apt-get install tesseract-ocr

import pytesseract
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'

from transformers import pipeline

# Initialize the document question answering pipeline
nlp = pipeline(
    "document-question-answering",
    model="impira/layoutlm-document-qa",
)

# Define the image URL
image_url = "https://media-cldnry.s-nbcnews.com/image/upload/t_fit-1500w,f_auto,q_auto:best/newscms/2019_26/1451579/seo_190619_letter_000_cover.jpg"

# Define the question
question = "What is the sender's address?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)

# Define the question
question = "What is the sender's name?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)

# Define the question
question = "zip?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)
# Out:
# Answer: [{'score': 0.9909729957580566, 'answer': '40 THEATRE STREET', 'start': 4, 'end': 6}]
# Answer: [{'score': 0.9990316033363342, 'answer': 'JANE H. DOE', 'start': 1, 'end': 3}]
# Answer: [{'score': 0.9241234660148621, 'answer': '85351', 'start': 10, 'end': 10}]

# %%
#!pip install pytesseract
#!sudo apt-get install tesseract-ocr

import pytesseract
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'

from transformers import pipeline

# Initialize the document question answering pipeline
nlp = pipeline(
    "document-question-answering",
    model="impira/layoutlm-document-qa",
)

# Define the image URL
#image_url = "https://media-cldnry.s-nbcnews.com/image/upload/t_fit-1500w,f_auto,q_auto:best/newscms/2019_26/1451579/seo_190619_letter_000_cover.jpg"
image_url = "https://www.post.japanpost.jp/img/int/use/writing/label_normal_en.gif"

# Define the question
question = "What is the sender's address in Tokyo?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)

# Define the question
question = "What is the sender's name?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)

# Define the question
question = " What is recipient's name?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)

# Define the question
question = " What is recipient's address?"

# Call the pipeline to answer the question based on the image
result = nlp(image_url, question)

# Print the answer
print("Answer:", result)
# Out:
# Answer: [{'score': 0.15057902038097382, 'answer': 't-tHagacho Haga ku', 'start': 16, 'end': 18}]
# Answer: [{'score': 0.998805820941925, 'answer': 'Riko Hagaki', 'start': 12, 'end': 13}]
# Answer: [{'score': 0.7429685592651367, 'answer': 'Buddy', 'start': 29, 'end': 29}]
# Answer: [{'score': 0.63627690076828, 'answer': 'Chicago, IL 60644-9998', 'start': 47, 'end': 49}]
